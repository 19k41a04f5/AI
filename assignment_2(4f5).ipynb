# %% [markdown]
# <a href="https://colab.research.google.com/github/19k41a04f5/AI/blob/main/assignment_2(4f5).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
x=np.random.uniform(-10,10)
eta=0.001
iter_max=300
iter=1
while iter<=iter_max :
 slope = 4*x*x*x + 6*x
 step_length = (-eta) * slope
 x=x+step_length
 iter=iter+1 
print("control variable = ",round(x))
obj = ((x*x*x*x)+(3*x*x)+10)
print("objective function = ",round(obj))
# Out:
# control variable =  0
# objective function =  10

# %% [markdown]
# ![WhatsApp Image 2021-09-15 at 9.01.45 PM (2).jpeg](data:image/jpeg;base64,...)
