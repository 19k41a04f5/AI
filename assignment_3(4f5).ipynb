# %% [markdown]
# <a href="https://colab.research.google.com/github/19k41a04f5/AI/blob/main/assignment_3(4f5).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import math
x=np.random.uniform(-10,10)
y=np.random.uniform(-10,10)
eta=0.1
iter_max=100
iter=1
while iter<=iter_max :
 slope_x=6*x
 slope_y=-5*(math.exp(-y))
 steplength_x=-eta*slope_x
 steplength_y=-eta*slope_y
 x=x+steplength_x
 y=y+steplength_y
 iter=iter+1
obj=3*x*x+5*(math.exp(-y))+10
print("objective function = ",round(obj),"at x=",round(x),", y=",round(y))
# Out:
# objective function =  10 at x= 0 , y= 1183

# %% [markdown]
# ![WhatsApp Image 2021-09-15 at 9.01.45 PM.jpeg](data:image/jpeg;base64,...)
